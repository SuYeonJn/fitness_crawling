# %%
# !pip install webdriver-manager
# Out:
# Collecting webdriver-manager
#   Downloading webdriver_manager-3.8.5-py2.py3-none-any.whl (27 kB)
# Collecting python-dotenv
#   Downloading python_dotenv-0.21.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: packaging in c:\users\82106\anaconda3\lib\site-packages (from webdriver-manager) (21.3)
# Requirement already satisfied: requests in c:\users\82106\anaconda3\lib\site-packages (from webdriver-manager) (2.28.1)
# Requirement already satisfied: tqdm in c:\users\82106\anaconda3\lib\site-packages (from webdriver-manager) (4.64.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\82106\anaconda3\lib\site-packages (from packaging->webdriver-manager) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\82106\anaconda3\lib\site-packages (from requests->webdriver-manager) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\82106\anaconda3\lib\site-packages (from requests->webdriver-manager) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\82106\anaconda3\lib\site-packages (from requests->webdriver-manager) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\82106\anaconda3\lib\site-packages (from requests->webdriver-manager) (2.0.4)
# Requirement already satisfied: colorama in c:\users\82106\anaconda3\lib\site-packages (from tqdm->webdriver-manager) (0.4.5)
# Installing collected packages: python-dotenv, webdriver-manager
# Successfully installed python-dotenv-0.21.0 webdriver-manager-3.8.5

# %%
# Out:
# [WDM] - Downloading: 100%|████████████████████████████████████████████████████████| 6.21M/6.21M [00:00<00:00, 11.9MB/s]

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup

driver = webdriver.Chrome(service= Service(ChromeDriverManager().install()))

url = "https://www.melon.com/chart/index.htm"
driver.get(url)
time.sleep(2)
html = driver.page_source

soup = BeautifulSoup(html, 'html.parser')

songs = soup.select('#lst50')
song = songs[0]
title = song.select('div.ellipsis.rank01 > span > a')[0]. text
print(title)

for song in songs:
    title = song.select('div.ellipsis.rank01 > span > a')[0]. text
    print(title)

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup

driver = webdriver.Chrome(service= Service(ChromeDriverManager().install()))

url = "https://www.melon.com/chart/index.htm"
driver.get(url)

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
    
songs = driver.find_elements('css selector', 'tr') [1:]
for song in songs:
    title = song.find_elements('css selector', 'div.ellipsis.rank01 > span > a')[0].text
    print(title)
# Out:
# 사건의 지평선
# ANTIFRAGILE
# Nxde
# Hype boy
# After LIKE
# 새삥 (Prod. ZICO) (Feat. 호미들)
# 사랑은 늘 도망가
# Rush Hour (Feat. j-hope of BTS)
# Attention
# LOVE DIVE
# 우리들의 블루스
# Monologue
# Shut Down
# 다시 만날 수 있을까
# London Boy
# 무지개
# Polaroid
# Pink Venom
# 이제 나만 믿어요
# 자격지심 (Feat. ZICO)
# 아버지
# A bientot
# 해요 (2022)
# 손이 참 곱던 그대
# 인생찬가
# 딱 10CM만
# 사랑해 진짜
# TOMBOY
# 그때 그 순간 그대로 (그그그)
# 연애편지
# 사랑인가 봐
# 내가 아니라도
# 그라데이션
# Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack] (Feat. FIFA Sound)
# 너의 모든 순간
# 우린 그렇게 사랑해서
# Cookie
# 보금자리
# 정이라고 하자 (Feat. 10CM)
# FEARLESS
# 나의 X에게
# 떠나보낼 준비해 둘걸 그랬어
# 취중고백
# That That (prod. & feat. SUGA of BTS)
# ELEVEN
# 보고싶었어
# That's Hilarious
# 다정히 내 이름을 부르면
# Dynamite
# 주저하는 연인들을 위해
# I Don't Think That I Like Her
# Left and Right (Feat. Jung Kook of BTS)
# 내 기쁨은 너가 벤틀리를 끄는 거야
# 모든 날, 모든 순간 (Every day, Every Moment)
# LOVE me
# Butter
# 새벽에 걸려온 너의 전화는
# FOREVER 1
# 고백연습
# 밤하늘의 별을(2020)
# 첫사랑
# 봄날
# Yet To Come
# STAY
# Love story
# Permission to Dance
# SNEAKERS
# 도깨비불 (Illusion)
# 봄여름가을겨울 (Still Life)
# 사랑한다고 말해줘
# The Astronaut
# LAW (Prod. Czaer)
# POP!
# 스티커 사진
# 내 손을 잡아
# Feel My Rhythm
# 신호등
# INVU
# 그래서 그대는
# strawberry moon
# 그중에 그대를 만나
# Off My Face
# 드라마
# Snowman
# MY BAG
# 회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)
# 통화연결음
# Next Level
# 늦은 밤 헤어지긴 너무 아쉬워
# 바보에게 바보가 (웹툰 '연애의 발견' X 이석훈)
# 나의 목소리로
# 못해
# 모든 계절은 너였다
# 오르트구름
# DICE
# 너를 생각해
# Girls
# GANADARA (Feat. 아이유)
# 인생은 뷰티풀
# I Ain't Worried

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup

driver = webdriver.Chrome(service= Service(ChromeDriverManager().install()))

url = "https://www.google.co.kr/maps/search/%ED%97%AC%EC%8A%A4%EC%9E%A5/data=!3m1!4b1?hl=ko"
driver.get(url)
time.sleep(2)
html = driver.page_source

soup = BeautifulSoup(html, 'html.parser')

songs = soup.select('.NrDZNb')
song = songs[0]
title = song.select('span')[0].text
#print(title)

def infinite_loop():
    # 최초 페이지 스크롤 설정
    # 스크롤 시키지 않았을 때의 전체 높이
    last_page_height = driver.execute_script("return document.documentElement.scrollHeight")

    while True:
        # 윈도우 창을 0에서 위에서 설정한 전체 높이로 이동
        driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
        time.sleep(2.0)
        # 스크롤 다운한 만큼의 높이를 신규 높이로 설정 
        new_page_height = driver.execute_script("return document.documentElement.scrollHeight")
        # 직전 페이지 높이와 신규 페이지 높이 비교
        if new_page_height == last_page_height:
            time.sleep(2.0)
            # 신규 페이지 높이가 이전과 동일하면, while문 break
            if new_page_height == driver.execute_script("return document.documentElement.scrollHeight"):
                break
                
        else:
            last_page_height = new_page_height
            
for song in songs:
    title = song.select('span')[0].text
    print(title)
    infinite_loop()
# Out:
# 짐인더하우스
# 짐박스피트니스 봉천점
# 피트니스FM 서울대
# 투엑스휘트니스 관악점
# 짐박스피트니스 신림2호점
# 피트니스FM 낙성대점

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup

driver = webdriver.Chrome(service= Service(ChromeDriverManager().install()))

url = "https://www.google.co.kr/maps/search/%ED%97%AC%EC%8A%A4%EC%9E%A5/data=!3m1!4b1?hl=ko"
driver.get(url)
time.sleep(2)
html = driver.page_source

soup = BeautifulSoup(html, 'html.parser')

songs = soup.select('.NrDZNb')
song = songs[0]
title = song.select('span')[0].text
#print(title)

import datetime

def doScrollDown(whileSeconds):
    start = datetime.datetime.now()
    end = start + datetime.timedelta(seconds=whileSeconds)
    while True:
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        time.sleep(1)
        if datetime.datetime.now() > end:
            break
            
doScrollDown(60)

for song in songs:
    title = song.select('span')[0].text
    print(title)
# Out:
# 짐인더하우스
# 짐박스피트니스 봉천점
# 피트니스FM 서울대
# 투엑스휘트니스 관악점
# 짐박스피트니스 신림2호점
# 피트니스FM 낙성대점

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup

driver = webdriver.Chrome(service= Service(ChromeDriverManager().install()))

url = "https://m.map.naver.com/search2/search.naver?query=%EA%B4%80%EC%95%85%EA%B5%AC%20%ED%97%AC%EC%8A%A4%EC%9E%A5&sm=hty&style=v5"
driver.get(url)
time.sleep(2)
html = driver.page_source

soup = BeautifulSoup(html, 'html.parser')

wrap = soup.select('li._item._lazyImgContainer')

title_list = []
section_list = []
address_list = []

for wraps in wrap:
    
    title = wraps.select('div.item_tit._title > strong')[0].text
    section = wraps.select('div.item_tit._title > em')[0].text
    address = wraps.select('div.wrap_item > a')[0].text.lstrip('주소보기').strip()
    
    #print(title, section, address)
    title_list.append(title)
    section_list.append(section)
    address_list.append(address)


#title_list
#section_list
#address_list

btn = driver.find_elements(By.CLASS_NAME, 'item_tit._title')[0]
btn.click()
time.sleep(1)
star = driver.find_elements(By.CLASS_NAME, 'PXMot.LXIwF')[0].text


data = {'헬스장 이름': title_list, '시설': section_list, '주소': address_list}
df = pd.DataFrame(data)
print(df, star)
# Out:
#             헬스장 이름     시설                                    주소
# 0      휘트니스FM 서울대점    헬스장         서울특별시 관악구 관악로 168 대우디오슈페리움2단지
# 1   휘트니스피플 우먼 서울대점    헬스장             서울특별시 관악구 관악로 199 상준빌딩 3층
# 2    휘트니스피플 우먼 신림점    헬스장             서울특별시 관악구 신림로 353 신영빌딩 5층
# 3      휘트니스FM 낙성대점    헬스장           서울특별시 관악구 남부순환로 1926 경동제약빌딩
# 4   자마이카 피트니스 신림역점    헬스장        서울특별시 관악구 신림로 340 르네상스 쇼핑몰 12층
# ..             ...    ...                                   ...
# 70            천프로짐  스포츠시설                  서울특별시 관악구 남현2길 62 1층
# 71           정피트니스  스포츠시설                 서울특별시 관악구 시흥대로 548 2층
# 72              오짐  스포츠시설  서울특별시 관악구 남부순환로 1917 베스킨라빈스 건물 2F,3F
# 73             제이짐    헬스장      서울특별시 관악구 남부순환로 1909 아이스타빌딩 지하1층
# 74         리메이크바디샵  스포츠시설    서울특별시 관악구 남부순환로 1888 지하1층 2호, 302호
#
# [75 rows x 3 columns] 별점
# 4.66/5

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\82106\anaconda3\lib\site-packages (3.0.10)
# Requirement already satisfied: et_xmlfile in c:\users\82106\anaconda3\lib\site-packages (from openpyxl) (1.1.0)

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import xlsxwriter

workbook = xlsxwriter.Workbook('fitness3.xlsx')
worksheet = workbook.add_worksheet()

driver = webdriver.Chrome(service= Service(ChromeDriverManager().install()))

url = "https://m.map.naver.com/search2/search.naver?query=%EA%B4%80%EC%95%85%EA%B5%AC%20%ED%97%AC%EC%8A%A4%EC%9E%A5&sm=hty&style=v5"
driver.get(url)
time.sleep(2)
html = driver.page_source

soup = BeautifulSoup(html, 'html.parser')

wrap = soup.select('li._item._lazyImgContainer')

"""
title_list = []
section_list = []
address_list = []
stars_list = []
price_list=[]
site_list=[]
"""

row = 0

btn = driver.find_elements(By.CLASS_NAME, 'item_tit._title')
for btns in btn:
    btns.click()
    time.sleep(1.5)
    
    title= driver.find_elements(By.CLASS_NAME, 'Fc1rA')[0].text
    section= driver.find_elements(By.CLASS_NAME, 'DJJvD')[0].text
    address= driver.find_elements(By.CLASS_NAME, 'IH7VW')[0].text
    try:
        stars= driver.find_elements(By.CLASS_NAME, 'PXMot.LXIwF')[0].text.lstrip('별점\n')
    except:
        stars = ''
    
    try:
        price = driver.find_elements(By.CLASS_NAME, 'X7q00.WVr9W')[0].text.strip()
    except:
        price = ''
        
    try:
        site = driver.find_elements(By.CLASS_NAME, 'CQDdi')[0].text.strip()
    except:
        site = ''
    
    try:
        review = driver.find_elements(By.CLASS_NAME, 'place_bluelink')[0].text
    except:
        review =''
        
    url = driver.current_url
    
    time.sleep(1)

    try: 
        picture = driver.find_elements(By.CLASS_NAME, 'xez5V')[0]
        picture.click()
        time.sleep(1)
        picture1 = driver.find_elements(By.CLASS_NAME, 'wzrbN')[0]
        image=  picture1.find_element(By.TAG_NAME, 'img')
        thumbnail = image.get_attribute("src")
    except:
        picture2 = driver.find_elements(By.CLASS_NAME, 'CEX4u')[0]
        picture2.click()
        time.sleep(1)
        picture1 = driver.find_elements(By.CLASS_NAME, 'wzrbN')[0]
        image=  picture1.find_element(By.TAG_NAME, 'img')
        thumbnail = image.get_attribute("src")
        bar = driver.find_elements(By.CLASS_NAME, 'flicking-viewport')[0]
        home = bar.find_elements(By.TAG_NAME,'a')[0]
        home.click()
        time.sleep(1)
   
    
    """
    title_list.append(title)
    section_list.append(section)
    address_list.append(address)
    stars_list.append(stars)
    price_list.append(price)
    site_list.append(site)
    """
    
    time.sleep(0.5)
    
    print(title, section, address, stars, price, site, review, url, thumbnail)
    

    worksheet.write(row, 0, title)
    worksheet.write(row, 1, section)
    worksheet.write(row, 2, address)
    worksheet.write(row, 3, stars)
    worksheet.write(row, 4, price)
    worksheet.write(row, 5, site)
    worksheet.write(row, 6, review)
    worksheet.write(row, 7, url)
    worksheet.write(row, 8, thumbnail)
    
    row += 1
    
    back = driver.find_elements(By.CLASS_NAME, 'DDfpb')[0]
    back.click()
    time.sleep(1)
    back.click()
    time.sleep(1)
workbook.close()
# Out:
# 휘트니스FM 서울대점 헬스장 서울 관악구 관악로 168 대우디오슈페리움2단지 4.65/5  https://blog.naver.com/fitnessfm4 방문자리뷰 555 https://m.place.naver.com/place/37207783/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221011_281%2F1665476298235F0OqC_JPEG%2FKUK09420%25C0%25A5.jpg
# 휘트니스FM 낙성대점 헬스장 서울 관악구 남부순환로 1926 경동제약빌딩 4.87/5 ★12개월/ 22년 결산 세일 특가!
# 330,000원
# 일일입장
# 15,000원 https://blog.naver.com/fitnessfm4 방문자리뷰 1,258 https://m.place.naver.com/place/36428472/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221206_9%2F16703183578571rM6N_JPEG%2F12%25BF%25F9_%25B0%25E1%25BB%25EA%25BC%25BC%25C0%25CF_%25BF%25C2%25B6%25F3%25C0%25CE%25BF%25EB.jpg
# 휘트니스피플 우먼 신림점 헬스장 서울 관악구 신림로 353 신영빌딩 5층 4.8/5  https://blog.naver.com/fpeoplew1 방문자리뷰 494 https://m.place.naver.com/place/37263903/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221029_268%2F16670337879390DLrz_JPEG%2F1666854678147.jpg
# 스포애니 보라매점 헬스장 서울 관악구 봉천로 227 보라매 샤르망 B1층 4.3/5 헬스+G.X. 3개월
# 90,000원
# 헬스+G.X. 6개월
# 180,000원
# 헬스+G.X. 1년
# 360,000원
# 일일이용(대여운동복포함)
# 10,000원
# 부가세 10%별도
# 변동 http://m.spoany.co.kr/branch/branch_detail.html?base_seq=OQ== 방문자리뷰 67 https://m.place.naver.com/place/13160344/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221007_193%2F1665137347349YrD3R_JPEG%2F%25BD%25BA%25C6%25F7%25BE%25D6%25B4%25CF%2528%25C7%25C7%25C6%25AE%25B4%25CF%25BD%25BA%2529.jpg
# 자마이카 휘트니스 서울대입구점 헬스장 서울 관악구 남부순환로 1820  회원권 최대 50% 할인 적용
# 변동
# 회원권 등록 시 G.X ( 요가,필라테스,에어로빅,방송댄스 ) 무상 이용
# 변동
# 운동복 최대 50% 할인
# 변동
# 락커 최대 50% 할인
# 변동 https://blog.naver.com/jamaicaseoul 방문자리뷰 208 https://m.place.naver.com/place/13473722/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221201_196%2F1669894374245UgDnk_JPEG%2FKakaoTalk_20221201_203100056.jpg
# 다조아짐 관악구청점 스포츠시설 서울 관악구 관악로 153 로얄빌딩 B1 다조아짐 관악구청점  1주년 특별 PT할인 이벤트
# 800,000원 https://dajoagymm2.modoo.at/ 방문자리뷰 32 https://m.place.naver.com/place/1089622691/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221118_17%2F1668758767376AVYzI_JPEG%2F33%25281%2529.jpg
# 스포짐 사당점 헬스장 서울 관악구 과천대로 939 르메이에르강남타운2 b3 4.73/5 가입비 면제 이벤트
# 무료 https://blog.naver.com/spogymsd 방문자리뷰 173 https://m.place.naver.com/place/37123041/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221109_50%2F1667992228759zW6AC_JPEG%2F%25C7%25CA%25B5%25E5%25B7%25CE%25B0%25ED.jpg
# 자마이카 피트니스 신림역점 헬스장 서울 관악구 신림로 340 르네상스 쇼핑몰 12층   https://blog.naver.com/jamaica8828588 방문자리뷰 494 https://m.place.naver.com/place/1817037890/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20220707_246%2F1657195429943Qyqjr_JPEG%2F%25C5%25A9%25B1%25E2%25BA%25AF%25C8%25AFDSCF1147.jpg
# 휘트니스피플 우먼 서울대점 헬스장 서울 관악구 관악로 199 상준빌딩 3층 4.87/5  https://blog.naver.com/fpeoplew1 방문자리뷰 329 https://m.place.naver.com/place/37653779/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221026_300%2F1666776422052yWwy3_JPEG%2F1666776365601.jpg
# MF토탈휘트니스 헬스장 서울 관악구 남부순환로 1474 상원빌딩 4층 5층 4.28/5  https://mftotal.com/ 방문자리뷰 471 https://m.place.naver.com/place/31427736/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20210908_22%2F1631079998347XEWJi_JPEG%2F1XP2QRVkVqP3IYzhaCxIrO6d.jpg
# 에스엠휘트니스 헬스장 서울 관악구 남부순환로 1479 3층 에스엠휘트니스 4.68/5 1개월
# 44,000원
# 3개월
# 99,000원
# 6개월
# 165,000원  방문자리뷰 31 https://m.place.naver.com/place/35652818/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221215_137%2F16710544351852ws0X_JPEG%2F%25C8%25B8%25BB%25E7_%25B8%25DE%25C0%25CE_%25B7%25CE%25B0%25ED33-01.jpg
# 제임스킬짐PT 스포츠시설 서울 관악구 관악로 163 3층 4.98/5 회원 만족도 99% 서울대입구PT
# 무료
# 네이버페이 무이자 카드결제 가능해요!
# 무료
# 1. 바디프로필반
# 변동
# 2. 체형교정운동반
# 변동
# 3. 재활운동반
# 변동
# 4. 시합 선수반
# 변동
# 5. 일반 PT 수업
# 변동
# 6. 시합 포징반
# 변동 https://blog.naver.com/wan4545 방문자리뷰 105 https://m.place.naver.com/place/37207749/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20220729_258%2F1659068896750o9WVv_PNG%2F%25C4%25B8%25C3%25B3.PNG
# 데일리짐&PT 봉천점 헬스장 서울 관악구 성현로 80 관악드림타운아파트 주상가동 3, 4층 301호, 404호   https://blog.naver.com/dailygym 방문자리뷰 130 https://m.place.naver.com/place/1119251229/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20220913_96%2F166304387780695fSJ_PNG%2F1.png
# 스포애니 은천점 헬스장 서울 관악구 은천로 51 은호빌딩 B1층 4.31/5 헬스 + G.X 3개월
# 90,000원
# 헬스 + G.X 6개월
# 180,000원
# 헬스 + G.X 1년
# 360,000원
# 일일이용(대여운동복포함)
# 10,000원
# 부가세 10%별도
# 변동 https://m.spoany.co.kr/branch/branch_detail.html?base_seq=MzM= 방문자리뷰 58 https://m.place.naver.com/place/37009416/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221005_92%2F1664945432101G4g5U_JPEG%2F%25BD%25BA%25C6%25F7%25BE%25D6%25B4%25CF%2528%25C7%25C7%25C6%25AE%25B4%25CF%25BD%25BA%2529.jpg
# 얼티밋크로스핏 서울대본점 헬스장 서울 관악구 남부순환로 1799 대영오피스텔 4.57/5  http://crossfit2ruda.blog.me/ 방문자리뷰 13 https://m.place.naver.com/place/36177503/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20160428_8%2F1461823827278dWPdU_JPEG%2F176378554046989_0.jpeg
# 동방짐 본점 헬스장 서울 관악구 호암로26길 17 현빌라트 4.54/5 PT9회(헬스포함)
# 294,000원
# 헬스3개월(다이어트반 포함)
# 132,000원
# 헬스1개월+헬 다이어트반(바디프로필 반)
# 199,000원
# 경찰체력시험반
# 변동
# PT5회 + 그룹8회 (헬스포함)
# 399,000원 http://www,dongbanggym.com/ 방문자리뷰 83 https://m.place.naver.com/place/18209749/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20170110_242%2F1484045374650Ay41u_JPEG%2F186060597951767_6.jpeg
# 아워피트니스 헬스장 서울 관악구 남부순환로 1793 지하1, 2층   https://blog.naver.com/our_fitness 방문자리뷰 80 https://m.place.naver.com/place/1006764448/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20220704_134%2F1656919467473tVHOs_JPEG%2FC2B44822-BC23-4F62-8EF1-EF14DF2966B7.jpeg
# 짐인더하우스 2호점 헬스장 서울 관악구 보라매로 13 지하 2층 4.71/5 라이트 회원권 (1년)
# 380,000원
# 라이트 회원권 (6개월)
# 220,000원
# 3개월회원권(추가비용없음)
# 159,000원
# 1년회원권(추가비용없음)
# 530,000원
# 일일권
# 25,000원 https://blog.naver.com/openorclose 방문자리뷰 41 https://m.place.naver.com/place/1827116020/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20210604_44%2F16228042496175THxU_JPEG%2FgJuBIV9NdzFz4gHl8YV78S6G.jpeg.jpg
# 파운드짐 신림역점 헬스장 서울 관악구 신림로 350 지하 1층 파운드짐 4.45/5  https://blog.naver.com/founds1 방문자리뷰 111 https://m.place.naver.com/place/1401450856/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20200513_8%2F1589356403670QI2nI_PNG%2FTkD24Ph5sZvQhJj2H8UcRwVy.png
# 크라운짐 헬스장 서울 관악구 미성길 27 4.68/5 헬스 1개월(운동복+수건)
# 60,000원
# 헬스 3개월(운동복+수건)
# 150,000원
# 헬스 6개월(운동복+수건)
# 260,000원 https://blog.naver.com/teamcrown 방문자리뷰 68 https://m.place.naver.com/place/34016838/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20220119_70%2F1642598502316lyNqm_JPEG%2F33.jpg
# 폴인핏 신림점 헬스장 서울 관악구 신림로67길 9 3층  Happy Time EVENT- 8회
# 440,000원
# Happy Time EVENT-16회
# 800,000원
# 1:1 PT 10회+헬스 회원권
# 600,000원
# Event 1:1 PT 20회+회원권
# 1,000,000원
# Event 1:1 PT 30회+회원권
# 1,400,000원
# 1개월 헬스 회원권
# 90,000원
# 3개월 헬스 회원권
# 180,000원
# 6개월 헬스 회원권
# 270,000원 https://www.instagram.com/fall_in_fit_ 방문자리뷰 31 https://m.place.naver.com/place/1762308656/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20220927_91%2F1664247744813cyP5U_JPEG%2FKakaoTalk_20220926_085129167_13.jpg
# 운동하는날 서울대봉천점 헬스장 서울 관악구 쑥고개로 75 광장빌딩 B1  [12월한정이벤트] 헬스12개월
# 300,000원
# [12월한정이벤트] 2:1PT 24회
# 650,000원
# [12월한정이벤트] 1:1PT 20회
# 990,000원 https://naver.me/FiLvXDRD 방문자리뷰 117 https://m.place.naver.com/place/1275339710/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20220804_199%2F1659605539713BbzI0_JPEG%2F7PX5KNfCKVod4tisrNU7Ue75.jpg
# 짐박스피트니스 낙성대점 헬스장 서울 관악구 남부순환로 1924 B2, B3층  구독 멤버십 BASIC
# 29,900원
# 구독 멤버십 PRO
# 53,800원
# 365일 PASS
# 270,000원
# 1회 이용권
# 15,000원
# 개인락커(월)
# 9,900원 https://gymboxx.co.kr/Nakseongdae 방문자리뷰 495 https://m.place.naver.com/place/1899398091/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221019_64%2F1666157328298SDHOK_JPEG%2F%25BD%25E6%25B3%25D7%25C0%25CF.jpg
# 더스페셜짐 헬스장 서울 관악구 남부순환로 1734 주원빌딩 7, 8층 4.53/5  https://www.instagram.com/tsgym9987 방문자리뷰 33 https://m.place.naver.com/place/34557216/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20220210_145%2F1644474665243P6kXW_JPEG%2F%25B8%25DE%25C0%25CE1.jpg
# 바운드짐 서울대입구역점 헬스장 서울 관악구 남부순환로 1798 지하1층   http://www.boundgym.com/ 방문자리뷰 229 https://m.place.naver.com/place/1333323901/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221124_101%2F166927869292587rI6_JPEG%2FKakaoTalk_20221124_171427439_01.jpg
# 피트니스FM 5번출구점 헬스장 서울 관악구 남부순환로 1817 Q타워 지하1층 4.78/5  https://blog.naver.com/fmfitness 방문자리뷰 623 https://m.place.naver.com/place/1656615449/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20220307_1%2F1646637807567UVwdS_PNG%2F%25C0%25DB%25BE%25F7%25BE%25C82_220307.png
# 스포애니 서울대입구점 헬스장 서울 관악구 남부순환로 1855 관악통일빌딩 지하 1층 4.31/5 헬스+G.X 3개월
# 90,000원
# 헬스+G.X 6개월
# 180,000원
# 헬스+G.X 1년
# 360,000원
# 일일이용(대여운동복포함)
# 10,000원
# 부가세 10%별도
# 변동 https://blog.naver.com/spoany08 방문자리뷰 79 https://m.place.naver.com/place/21888953/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221005_52%2F1664954004668fDgSk_JPEG%2FKakaoTalk_20221005_145553325.jpg
# 짐박스피트니스 신림3호점 헬스장 서울 관악구 신림로23길 16 1층 짐박스피트니스 4.74/5 구독 멤버십 BASIC
# 39,900원
# 구독 멤버십 PRO
# 53,800원
# 365일 PASS
# 360,000원
# 1회 이용권
# 15,000원
# 개인락커 (1개월)
# 9,900원
# 회원복 (1개월)
# 3,000원 https://gymboxx.co.kr/Sillim3 방문자리뷰 98 https://m.place.naver.com/place/1282157591/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221019_57%2F1666157403464cRXF5_JPEG%2F%25BD%25E6%25B3%25D7%25C0%25CF.jpg
# 고핏 퍼스널트레이닝 헬스장 서울 관악구 신림로64길 43 5/5 10회
# 600,000원
# 20회
# 1,100,000원
# 30회
# 1,500,000원 https://blog.naver.com/go_fit 방문자리뷰 102 https://m.place.naver.com/place/1843842400/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20171114_171%2F1510597279684EIzCA_JPEG%2FcMALs9fK_JTgorAdsnbxsir4.jpg
# 더 슈트 헬스장 서울 관악구 신림로15길 3 3-5층  1개월
# 60,000원
# 3개월 (이벤트)
# 90,000원
# 6개월 (이벤트)
# 160,000원
# PT 10회
# 390,000원
# PT 20회
# 720,000원
# PT 30회
# 990,000원
# 1일권
# 8,000원
# PT 1회
# 60,000원 https://www.instagram.com/thesuit_fitness 방문자리뷰 17 https://m.place.naver.com/place/1233305373/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221216_25%2F1671191743131sm8YV_JPEG%2F1.jpg
# 스포애니 사당역점 헬스장 서울 관악구 남부순환로 2064 네스코엔타워 지하1층 스포애니 사당역점  부가세 10% 별도
# 변동
# 일일이용(대여운동복포함)
# 15,000원
# 헬스+G.X 1년(부가세별도)
# 480,000원
# 헬스+G.X 6개월(부가세별도)
# 240,000원
# 헬스+G.X 3개월(부가세별도)
# 120,000원 http://www.spoany.co.kr/branch/branch_detail.html?base_seq=MTE3 방문자리뷰 5 https://m.place.naver.com/place/1282116811/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221017_29%2F1665985086109gRiku_JPEG%2F%25BD%25BA%25C6%25F7%25BE%25D6%25B4%25CF%2528%25C7%25C1%25B7%25CE%2529.jpg
# 휘트니스 에일린 봉천점 헬스장 서울 관악구 남부순환로 1733 정민빌딩 B1   https://blog.naver.com/yoondo211 방문자리뷰 51 https://m.place.naver.com/place/1998357112/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221208_125%2F1670478433677BB2cA_JPEG%2FArtboard_2.jpg
# 피트니스 슈트 헬스장 서울 관악구 호암로26길 47 B1, 2, 3층 4.67/5  https://blog.naver.com/fitnesssuit 방문자리뷰 23 https://m.place.naver.com/place/1908862431/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20200821_90%2F15980209561403NfRB_JPEG%2F780g7zPfdUjY2c_yNGlRVuJy.jpg
# 짐박스피트니스 신림역점 헬스장 서울 관악구 신림로59길 14 5층  구독 멤버십 BASIC
# 36,900원
# 구독 멤버십 PRO
# 53,800원
# 365일 PASS
# 270,000원
# 1회 이용권
# 15,000원
# 개인락커 (1개월)
# 9,900원 https://gymboxx.co.kr/Sillimstation 방문자리뷰 501 https://m.place.naver.com/place/1989150653/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221019_116%2F1666157373011t04Kt_JPEG%2F%25BD%25E6%25B3%25D7%25C0%25CF.jpg
# 휘트니스 에일린 낙성대점 헬스장 서울 관악구 남부순환로 1940 B1층 휘트니스 에일린 낙성대점 4.95/5  https://blog.naver.com/choyoungdo12 방문자리뷰 319 https://m.place.naver.com/place/1273286981/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221208_134%2F1670478253863OSvwa_JPEG%2FArtboard_2.jpg
# 다조아짐 본점 스포츠시설 서울 관악구 관악로17길 25 다조아짐 4.98/5 다조아짐 본점 4주년 기념 이벤트!
# 800,000원 https://www.instagram.com/dajoa_gym 방문자리뷰 181 https://m.place.naver.com/place/1852581367/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221202_24%2F1669990876914JsCCY_JPEG%2F1669990807869.jpg
# 2351필라테스&짐 헬스/PT/그룹필라테스 헬스장 서울 관악구 남부순환로 1369 (관악농협 농산물백화점) 4.5/5 헬스 3개월(카드결제 부가세10%)
# 120,000원
# 헬스 6개월(카드결제 부가세10%)
# 165,000원
# 헬스 12개월(카드결제 부가세10%)
# 240,000원
# 1:1 PT(EVENT 참고)
# 무료
# 필라)1대7그룹수업(이벤트참고)
# 무료 https://www.instagram.com/2351_pilates_gym 방문자리뷰 44 https://m.place.naver.com/place/1872960025/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221125_235%2F1669385638391VM5fK_PNG%2F%25C1%25A6%25B8%25F1%25C0%25BB_%25C0%25D4%25B7%25C2%25C7%25D8%25C1%25D6%25BC%25BC%25BF%25E4_-001.png
# 유얼스짐PT 신대방역점 스포츠시설 서울 관악구 난곡로 357 202호 5/5 1회권
# 80,000원
# 10회권
# 600,000원
# 20회권
# 1,100,000원
# 30회권
# 1,600,000원
# 40회권
# 2,100,000원
# 50회권
# 2,500,000원 https://blog.naver.com/yours_gym21 방문자리뷰 200 https://m.place.naver.com/place/1147253493/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20211012_143%2F1634006355025Hq64w_JPEG%2FQtd1kUc4w9drdBBHQ-QO2rYt.jpg
# 블랙멀티짐 서울대점 헬스장 서울 관악구 관악로 217 10층 4.71/5 헬스 3개월
# 210,000원
# 헬스 6개월
# 300,000원
# 헬스 12개월
# 450,000원
# 헬스+스피닝 3개월
# 270,000원
# 헬스+스피닝 6개월
# 400,000원
# 헬스+스피닝 12개월
# 570,000원 https://blog.naver.com/songic902 방문자리뷰 147 https://m.place.naver.com/place/1122312234/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221213_136%2F1670916005612XltE1_JPEG%2FKakaoTalk_20221209_204502587_08.jpg
# 짐박스피트니스 봉천점 헬스장 서울 관악구 청룡1길 2 5, 6, 7층 짐박스피트니스 4.52/5 구독 멤버십 BASIC
# 43,900원
# 구독 멤버십 PRO
# 53,800원
# 365일 PASS
# 360,000원
# 1회 이용권
# 15,000원
# 개인락커 (1개월)
# 9,900원
# 회원복 (1개월)
# 3,000원 https://gymboxx.co.kr/bongcheon 방문자리뷰 290 https://m.place.naver.com/place/1227590558/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221019_52%2F1666157345747vudW4_JPEG%2F%25BD%25E6%25B3%25D7%25C0%25CF.jpg
# 더짐혼2호점 스포츠시설 서울 관악구 신원로 13 2층 더짐혼   https://thegymhon2022.modoo.at 방문자리뷰 54 https://m.place.naver.com/place/1613101900/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221110_122%2F1668049770540BfP2L_JPEG%2F58C39C51-4C4B-4570-972E-50132A228248.jpeg
# DOB휘트니스 봉천점 헬스장 서울 관악구 은천로 95 벽산블루밍상가 1층   http://cafe.naver.com/dobfitness 블로그리뷰 2 https://m.place.naver.com/place/1626255443/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20190905_96%2F15676777674499WmTP_JPEG%2FSwAek86TKrMgSYeAgZFhQ3H9.jpg
# 러너스하이 피트니스 신림 헬스장 서울 관악구 남부순환로 1603 러너스하이 피트니스  무료체험 수업 신청하기!
# 무료
# 3개월 수강권(레슨 횟수 제한 x)
# 645,000원
# 10회 수강권
# 250,000원
# 1개월 수강권(레슨 횟수 제한 x)
# 270,000원
# 6개월 수강권(레슨 횟수 제한 x)
# 1,080,000원 https://runnershigh.co.kr 방문자리뷰 538 https://m.place.naver.com/place/1185314179/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20220706_255%2F16570862417902VuUi_PNG%2F%25C1%25A6%25B8%25F1%25C0%25BB_%25C0%25D4%25B7%25C2%25C7%25CF%25BC%25BC%25BF%25E4_%25282%2529.png
# 슬림한바디PT 서울대입구점 스포츠시설 서울 관악구 남부순환로 1808 2층 1호 5/5 프로그램 등록시 헬스 12개월 증정
# 무료
# 네이버페이 최대 12개월 무이자 가능
# 무료
# 1:1 페이백 PT (15회)
# 980,000원
# 2:1 페이백 PT (13회)
# 545,000원
# 1:1 베이직 PT (20회)
# 1,200,000원
# 2:1 베이직 PT (10회)
# 385,000원
# 1:1 PT 체험 (1회)
# 20,000원
# 2:1 PT 체험 (1회)
# 30,000원 https://www.slimhanbody.com 방문자리뷰 218 https://m.place.naver.com/place/1584925367/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221214_59%2F1670992326569av4MJ_JPEG%2F6.jpg
# 피스트 서울대입구역점 헬스장 서울 관악구 봉천로 456 지하1층 피스트 팀트레이닝 서울대입구   https://fistteam.modoo.at/ 방문자리뷰 296 https://m.place.naver.com/place/1528196450/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20211122_105%2F1637567043566UkvM1_JPEG%2F8FA64436-1516-4633-A275-E34B7CF75F58.jpeg
# 에이오짐 PT&헬스 신림점 헬스장 서울 관악구 신림로64길 9 3층   https://blog.naver.com/aogym 방문자리뷰 49 https://m.place.naver.com/place/1309466972/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221115_191%2F1668504568582mHjRM_PNG%2F1668409789194.png
# 스포애니 낙성대점 헬스장 서울 관악구 인헌6길 15 3층, 4층 4.1/5 헬스+G.X 3개월
# 90,000원
# 헬스+G.X 6개월
# 180,000원
# 헬스+G.X 1년
# 360,000원
# 일일이용(대여운동복포함)
# 10,000원
# 부가세 10%별도
# 변동 https://m.spoany.co.kr/branch/branch_detail.html?base_seq=MTI= 방문자리뷰 41 https://m.place.naver.com/place/33534975/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221005_162%2F1664970998317bPTIR_JPEG%2F%25BD%25BA%25C6%25F7%25BE%25D6%25B4%25CF%2528%25C7%25C7%25C6%25AE%25B4%25CF%25BD%25BA%2529.jpg
# 짐박스피트니스 신림본점 헬스장 서울 관악구 신림로 90 대신빌딩 5층 4.61/5 구독 멤버십 BASIC
# 36,900원
# 구독 멤버십 PRO
# 53,800원
# 365일 PASS
# 320,000원
# 1회 이용권
# 15,000원
# 개인락커 (1개월)
# 9,900원
# 회원복 (1개월)
# 3,000원 https://gymboxx.co.kr/Sillim 방문자리뷰 149 https://m.place.naver.com/place/1626283420/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221019_57%2F1666157313247WlDAn_JPEG%2F%25BD%25E6%25B3%25D7%25C0%25CF.jpg
# 크로스핏 쿠타짐 헬스장 서울 관악구 인헌길 14 지하1층 쿠타짐 4.9/5  https://kutagym2.modoo.at 방문자리뷰 151 https://m.place.naver.com/place/37323151/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20171129_290%2F1511938893337JCqIJ_JPEG%2FcOOcmXA-SpMSPbE1rStPi6rN.jpg
# 제임스짐휘트니스 청림점 헬스장 서울 관악구 관악로 304 현대상가 1동 2층 5호 6호 4.65/5 헬스 1개월(요가무료)
# 110,000원
# 헬스 3개월(요가무료)
# 190,000원
# 헬스 6개월(요가무료)
# 290,000원
# 헬스 12개월(요가무료)
# 490,000원 http://jamesgym.co.kr/ 방문자리뷰 56 https://m.place.naver.com/place/197090464/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20200121_228%2F1579580178097mV1MV_JPEG%2FNhOPFJAeobIQw-q1o5D-lHGW.jpg
# 럭키 헬스클럽 헬스장 서울 관악구 신림로 272 대원빌딩 4층   https://blog.naver.com/conditionf1 방문자리뷰 17 https://m.place.naver.com/place/20277662/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20181228_281%2F1545994426270XTVPP_PNG%2FJQndXflpzcIMUM8PeTBxNFzA.png
# 에이치코어 서울대입구점 스포츠시설 서울 관악구 봉천로 485 6층 5/5  https://blog.naver.com/wjdgh88823 방문자리뷰 12 https://m.place.naver.com/place/1416081403/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20220325_94%2F1648180353343SExNH_PNG%2F02-%25B9%25E8%25B3%25CA.png
# 이너멜 피트니스 헬스장 서울 관악구 신림로 132 2층  회원권3개월
# 160,000원
# 회원권6개월
# 270,000원
# 회원권12개월
# 400,000원 https://oenomelfit.modoo.at 방문자리뷰 18 https://m.place.naver.com/place/1149234119/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20220217_181%2F16450336096101J1GM_JPEG%2F02.jpg
# 짐박스피트니스 난곡점 헬스장 서울 관악구 난곡로 210 6,7층 4.71/5 구독 멤버십 BASIC
# 43,900원
# 구독 멤버십 PRO
# 53,800원
# 365일 PASS
# 360,000원
# 1회 이용권
# 15,000원
# 개인락커 (1개월)
# 9,900원
# 회원복 (1개월)
# 3,000원 https://gymboxx.co.kr/nangok 방문자리뷰 183 https://m.place.naver.com/place/1992995991/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221019_106%2F1666157361306gdl1r_JPEG%2F%25BD%25E6%25B3%25D7%25C0%25CF.jpg
# 얼티밋크로스핏 난곡점 헬스장 서울 관악구 남부순환로 1464    방문자리뷰 7 https://m.place.naver.com/place/37434594/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20160425_288%2F1461571020076Dyxou_JPEG%2F176375568679856_0.jpeg
# 에이치코어 낙성대점 스포츠시설 서울 관악구 남부순환로 1921 지하1층 에이치코어 낙성대점   https://blog.naver.com/wogh03125 방문자리뷰 10 https://m.place.naver.com/place/1565388604/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20220105_63%2F16413674657449QKA1_PNG%2F03-%25B9%25E8%25B3%25CA.png
# 더짐혼PT 신림점 스포츠시설 서울 관악구 신림로 300 웅산빌딩 2층 5/5  https://blog.naver.com/thegymhon2017 방문자리뷰 129 https://m.place.naver.com/place/766635562/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20220802_60%2F1659422879978Iq65s_JPEG%2F%25A4%25B1%25A4%25B1%25A4%25B1%25A4%25B1%25A4%25B1%25A4%25B1.jpg
# 근육터짐 지방빠짐 헬스장 서울 관악구 남부순환로 2062 장수약국건물 3층 5/5 PT 10회
# 660,000원
# PT 20회
# 1,210,000원
# PT 30회
# 1,650,000원 https://www.instagram.com/zzoom.t/ 방문자리뷰 87 https://m.place.naver.com/place/506955709/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20220712_125%2F1657616630925XO5qi_JPEG%2F0BAAFBE3-34FF-4B5C-8070-4C51A039AE71.jpeg
# 짐박스피트니스 신림2호점 헬스장 서울 관악구 대학길 17 B1, 2, 3층 짐박스피트니스 4.72/5 구독 멤버십 BASIC
# 39,900원
# 구독 멤버십 PRO
# 53,800원
# 365일 PASS
# 360,000원
# 1회 이용권
# 15,000원
# 회원복 (1개월)
# 3,000원
# 개인락커 (1개월)
# 9,900원 https://gymboxx.co.kr/Sillim2 방문자리뷰 21 https://m.place.naver.com/place/1769165942/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221019_47%2F1666157416249A7ae6_JPEG%2F%25BD%25E6%25B3%25D7%25C0%25CF.jpg
# 온오프짐 여성전용PT 스포츠시설 서울 관악구 봉천로 217-1 4층  PT 20회(회당) EVENT
# 52,250원
# PT등록시 헬스 무제한 무료
# 무료
# 네이버 스토어에서 PT할인가 구매가능
# 무료
# 오후타임 PT 30% 할인
# 무료
# PT끝난후 헬스 3개월
# 99,000원 http://onoffgym.com/ 방문자리뷰 60 https://m.place.naver.com/place/1965934169/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221007_168%2F1665126314233MzqQF_PNG%2Fprofile_naver_place.png
# 혁PT 낙성대점 헬스장 서울 관악구 남부순환로 1939 태양빌딩 4.85/5  https://blog.naver.com/go-rush 방문자리뷰 49 https://m.place.naver.com/place/36305263/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221206_274%2F1670302615691mJWfp_JPEG%2F4F899C80-CD74-4F4B-87D3-72954B943B03.jpeg
# GYM In The house 헬스장 서울 관악구 관악로 195 관악위버폴리스 B동 2층 4.25/5 1개월(추가비용없음)
# 110,000원
# 3개월(추가비용없음)
# 220,000원
# 6개월(추가비용없음)
# 330,000원
# 1년(추가비용없음)
# 550,000원 https://blog.naver.com/openorclose 방문자리뷰 33 https://m.place.naver.com/place/715966597/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20161208_183%2F1481178190633lqK1k_JPEG%2F177158555329765_0.jpeg
# 리메이크바디샵 본점 스포츠시설 서울 관악구 남부순환로 1888 지하1층 2호, 302호  대표자PT
# 150,000원
# 트레이너PT
# 110,000원 https://blog.naver.com/chance7665 방문자리뷰 127 https://m.place.naver.com/place/116799071/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20191022_290%2F1571723353952YDEzR_JPEG%2FY_WfF2hGMKaJSEXDNHOFZVdm.jpg
# 유얼스짐PT 구로디지털점 스포츠시설 서울 관악구 조원로 10-1 2층 4.98/5 1회권
# 80,000원
# 10회권
# 600,000원
# 20회권
# 1,100,000원
# 30회권
# 1,600,000원
# 40회권
# 2,100,000원
# 50회권
# 2,500,000원 https://smartstore.naver.com/yoursgym 방문자리뷰 217 https://m.place.naver.com/place/1434675982/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221121_61%2F166899753528652DU4_JPEG%2FKakaoTalk_20221121_112357941_07.jpg
# 런 서울대입구 헬스장 서울 관악구 남부순환로 1832 오선빌딩 지하1층 4.8/5  https://www.projectrun.co.kr 방문자리뷰 155 https://m.place.naver.com/place/1379439578/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20211206_81%2F1638784270950t0Te8_PNG%2FKakaoTalk_Photo_2021-08-14-11-54-20_001.png
# 투엑스휘트니스 봉천점 헬스장 서울 관악구 청림6길 3 관악 푸르지오상가 4F 4.48/5  http://www.2xfitness.co.kr 방문자리뷰 88 https://m.place.naver.com/place/38478577/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20220418_140%2F1650262825442RopHe_JPEG%2FKakaoTalk_20220416_174340199.jpg
# 짐박스피트니스 신림4호점 헬스장 서울 관악구 신림로 198 3,4층 짐박스피트니스 4.64/5 구독 멤버십 BASIC
# 39,900원
# 구독 멤버십 PRO
# 53,800원
# 365일 PASS
# 360,000원
# 1회 이용권
# 15,000원
# 개인락커 (1개월)
# 9,900원
# 회원복 (1개월)
# 3,000원 https://gymboxx.co.kr/Sillim4 방문자리뷰 63 https://m.place.naver.com/place/1002233858/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221019_165%2F1666157390772Dbh6u_JPEG%2F%25BD%25E6%25B3%25D7%25C0%25CF.jpg
# 동방짐피트니스 헬스장 서울 관악구 신림로 266 3층  헬스 3개월
# 132,000원
# 헬 다이어트 바디프로필 반
# 218,000원
# 1대1PT 10회 (헬스포함)
# 356,000원 https://blog.naver.com/dongbanggym 방문자리뷰 12 https://m.place.naver.com/place/1382178948/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20220426_173%2F1650961141382T8u67_JPEG%2F1650955170119-1.jpg
# 김코치 1호점 스포츠시설 서울 관악구 봉천로 575 6층 4.99/5  https://blog.naver.com/kimcoach1015 방문자리뷰 133 https://m.place.naver.com/place/1325107447/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20210116_183%2F1610770225270fsY6C_JPEG%2F9Mmu7pCsF394jykXGs1Jz_zc.jpg
# 파운드짐 신대방역점 헬스장 서울 관악구 난곡로 367 경신빌딩 4.67/5 헬스 1개월
# 77,000원
# 헬스 3개월
# 165,000원
# 헬스 6개월
# 264,000원
# 헬스 12개월
# 330,000원
# P.T
# 60,500원 https://blog.naver.com/foundgym 방문자리뷰 17 https://m.place.naver.com/place/38692893/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20161013_290%2F1476342291362r09xd_JPEG%2F176960605866790_2.jpeg
# 터틀짐 스포츠시설 서울 관악구 조원로 56 4.89/5  https://blog.naver.com/turtlegym 방문자리뷰 158 https://m.place.naver.com/place/1639610584/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20190325_3%2F1553478587267zxv56_PNG%2FpTg_4vmH633VJ3qmEi_NLA41.png
# 정피트니스 스포츠시설 서울 관악구 시흥대로 548 2층 5/5 1:1PT10회(50분) 부가세포함
# 495,000원 https://blog.naver.com/junginyeol 방문자리뷰 54 https://m.place.naver.com/place/1136754722/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221208_107%2F1670501544538dvETj_JPEG%2F20221206_143053.jpg
# 바디컨트롤 PT & 그룹PT 트레이닝센터 신림대학동점 스포츠시설 서울 관악구 신림로 108 운용빌딩 지하1층 5/5 1:1 PT 10회 특가 할인
# 440,000원
# 그룹PT 3달간 주 2회
# 288,000원
# 그룹PT 20회
# 200,000원
# 그룹PT 10회 > 12회
# 160,000원
# 1:1 PT 30회
# 1,650,000원
# 오픈매트 4주
# 무료
# 그룹PT 30회
# 360,000원
# 그룹클래스 1회
# 20,000원 https://blog.naver.com/bcsillim 방문자리뷰 30 https://m.place.naver.com/place/36917083/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20220803_88%2F1659519998709iHljh_JPEG%2F%25B9%25AB%25B7%25E1%25C3%25BC%25C7%25E8.jpg
# 모아핏휘트니스 낙성대점 헬스장 서울 관악구 남부순환로 1905 태신빌딩 5층 4.96/5 일일이용권
# 11,000원 https://blog.naver.com/moafit_ness 방문자리뷰 240 https://m.place.naver.com/place/1278950206/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20200413_57%2F1586768872061DzKwv_JPEG%2FhH9cHUQVuN1lcKr4SO6kt1UP.jpg
# 데일리PT 헬스장 서울 관악구 난곡로 105 2층  그룹PT 10회(50분 웨이트 수업)
# 350,000원
# 그룹PT 30회(50분 웨이트 수업)
# 735,000원
# 무제한 그룹PT(1개월)
# 450,000원
# 무제한 그룹PT(3개월)
# 940,000원
# 수험생 그룹PT 10회
# 250,000원
# 수험생 무제한 그룹PT 1개월
# 350,000원 https://blog.naver.com/dailypt 방문자리뷰 18 https://m.place.naver.com/place/1413620265/home https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221202_149%2F1669914113019tgbru_PNG%2F%25C1%25A6%25B8%25F1%25C0%25BB_%25C0%25D4%25B7%25C2%25C7%25D8%25C1%25D6%25BC%25BC%25BF%25E4_-001.png
